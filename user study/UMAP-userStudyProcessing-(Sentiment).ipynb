# %%
import pandas as pd
df_personal_info = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.personal_info.csv")
df_ghs_fk = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.ghs_fk.csv")
df_evaluatechoices1 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices.csv")
df_evaluatechoices2 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices2.csv")
df_evaluatechoices3 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices3.csv")
df_evaluatechoices4 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices4.csv")
df_evaluatechoices5 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices5.csv")
df_evaluatechoices6 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices6.csv")
df_evaluatechoices7 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices7.csv")
df_evaluatechoices8 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices8.csv")
df_evaluatechoices9 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices9.csv")
df_evaluatechoices10 = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.evaluatechoices10.csv")
articles = pd.read_csv("C:/data/UserStudy/1103Python/Labels_Nudges.climatenewsBOM.csv")
#df2 = pd.DataFrame(csv_input2)
#personal_infoAndghs_fk = pd.merge(df_personal_info, df_ghs_fk, on='person')

# %%
df_evaluatechoices1
# Out:
#       id            title  person         liked_news         trust_news  \
# 0     77  EvaluateChoices      96  Strongly_Disagree           Disagree
# 1     78  EvaluateChoices      97           Disagree            Neutral
# 2     79  EvaluateChoices      98              Agree              Agree
# 3     80  EvaluateChoices      99     Strongly_Agree              Agree
# 4     81  EvaluateChoices     100     Strongly_Agree     Strongly_Agree
# ..   ...              ...     ...                ...                ...
# 202  280  EvaluateChoices     329              Agree              Agree
# 203  281  EvaluateChoices     330     Strongly_Agree              Agree
# 204  282  EvaluateChoices     331     Strongly_Agree     Strongly_Agree
# 205  283  EvaluateChoices     333     Strongly_Agree     Strongly_Agree
# 206  284  EvaluateChoices     334              Agree  Strongly_Disagree
#
#         fit_preference     recommend_news many_to_choose  created  \
# ...

# %%
# The below is used to extrct which column we want to keep in new df
df_evaluatechoices1 = df_evaluatechoices1[["person","created","liked_news"]]
df_evaluatechoices2 = df_evaluatechoices2[["person","created","liked_news"]]
df_evaluatechoices3 = df_evaluatechoices3[["person","created","liked_news"]]
df_evaluatechoices4 = df_evaluatechoices4[["person","created","liked_news"]]
df_evaluatechoices5 = df_evaluatechoices5[["person","created","liked_news"]]
df_evaluatechoices6 = df_evaluatechoices6[["person","created","liked_news"]]
df_evaluatechoices7 = df_evaluatechoices7[["person","created","liked_news"]]
df_evaluatechoices8 = df_evaluatechoices8[["person","created","liked_news"]]
df_evaluatechoices9 = df_evaluatechoices9[["person","created","liked_news"]]
df_evaluatechoices10 = df_evaluatechoices10[["person","created","liked_news"]]

# %%
df_evaluatechoices1
# Out:
#      person  created         liked_news
# 0        96       39  Strongly_Disagree
# 1        97       60           Disagree
# 2        98       97              Agree
# 3        99       92     Strongly_Agree
# 4       100       63     Strongly_Agree
# ..      ...      ...                ...
# 202     329        1              Agree
# 203     330        2     Strongly_Agree
# 204     331       49     Strongly_Agree
# 205     333       15     Strongly_Agree
# 206     334       97              Agree
#
# [207 rows x 3 columns]

# %%
df_evaluatechoices2
# Out:
#      person  created      liked_news
# 0        96       61  Strongly_Agree
# 1        97       81           Agree
# 2        98       99         Neutral
# 3        99       91  Strongly_Agree
# 4       100       70  Strongly_Agree
# ..      ...      ...             ...
# 190     330       33  Strongly_Agree
# 191     331       27  Strongly_Agree
# 192     322       18  Strongly_Agree
# 193     333       45  Strongly_Agree
# 194     334       99           Agree
#
# [195 rows x 3 columns]

# %%
# The below is used to contact two dataset for data analytics
result1and2 = pd.concat([df_evaluatechoices1, df_evaluatechoices2], axis="rows",ignore_index=True)

# %%
pd.set_option('display.max_rows', None)
result1and2
# Out:
#      person  created         liked_news
# 0        96       39  Strongly_Disagree
# 1        97       60           Disagree
# 2        98       97              Agree
# 3        99       92     Strongly_Agree
# 4       100       63     Strongly_Agree
# 5       101       80              Agree
# 6       103       65     Strongly_Agree
# 7       106      100     Strongly_Agree
# 8       102       28           Disagree
# 9       107       55     Strongly_Agree
# 10      105       71     Strongly_Agree
# 11      108       36              Agree
# 12      110       91     Strongly_Agree
# 13      112       67     Strongly_Agree
# 14      114       77     Strongly_Agree
# 15      109       47     Strongly_Agree
# 16      113       40     Strongly_Agree
# 17      111        7     Strongly_Agree
# 18      115       59     Strongly_Agree
# 19      116       64     Strongly_Agree
# 20      117       99              Agree
# 21      120       59              Agree
# ...

# %%
result1and2.value_counts('liked_news')
# Out:
# liked_news
# Strongly_Agree       231
# Agree                138
# Neutral               15
# Disagree              13
# Strongly_Disagree      5
# dtype: int64

# %%
#The below is used to make person in order

# %%
result1and2 = result1and2.sort_values(by='person', ascending=True,ignore_index=True)

# %%
result1and2
# Out:
#      person  created         liked_news
# 0        96       39  Strongly_Disagree
# 1        96       61     Strongly_Agree
# 2        97       60           Disagree
# 3        97       81              Agree
# 4        98       97              Agree
# 5        98       99            Neutral
# 6        99       92     Strongly_Agree
# 7        99       91     Strongly_Agree
# 8       100       63     Strongly_Agree
# 9       100       70     Strongly_Agree
# 10      101        4     Strongly_Agree
# 11      101       80              Agree
# 12      102       28           Disagree
# 13      103       65     Strongly_Agree
# 14      103       71     Strongly_Agree
# 15      105       71     Strongly_Agree
# 16      105       26     Strongly_Agree
# 17      106      100     Strongly_Agree
# 18      106       32            Neutral
# 19      107       55     Strongly_Agree
# 20      107       32     Strongly_Agree
# 21      108       72     Strongly_Agree
# ...

# %%
# Now let's contact 10 dataframe

# %%
pdList = [df_evaluatechoices1, df_evaluatechoices2,df_evaluatechoices3,df_evaluatechoices4,df_evaluatechoices5,df_evaluatechoices6,df_evaluatechoices7,df_evaluatechoices8,df_evaluatechoices9,df_evaluatechoices10]  # List of your dataframes
result1to10 = pd.concat(pdList, axis="rows",ignore_index=True)

# %%
#pd.set_option('display.max_rows', None)
#result1to10

# %%
result1to10.value_counts('liked_news')
# Out:
# liked_news
# Strongly_Agree       1049
# Agree                 618
# Disagree              104
# Neutral                91
# Strongly_Disagree      27
# dtype: int64

# %%
# The below is for remove the abscent users, who do not join 1o news in the end, and be approved from Prolific

# %%
result1to10 = result1to10[result1to10['person'].isin(df_evaluatechoices10['person'])]

# %%
#The below is used to make person in order

# %%
result1to10 = result1to10.sort_values(by='person', ascending=True,ignore_index=True)

# %%
result1to10.columns = ['person','id','liked_news']

# %%
result1to10
# Out:
#       person   id         liked_news
# 0         96   39  Strongly_Disagree
# 1         96   82     Strongly_Agree
# 2         96  100            Neutral
# 3         96    7           Disagree
# 4         96   61     Strongly_Agree
# 5         96   19     Strongly_Agree
# 6         96   32     Strongly_Agree
# 7         96   31           Disagree
# 8         96   28              Agree
# 9         96   69  Strongly_Disagree
# 10        97   27     Strongly_Agree
# 11        97   88  Strongly_Disagree
# 12        97   33     Strongly_Agree
# 13        97   81              Agree
# 14        97   22           Disagree
# 15        97   23           Disagree
# 16        97   29              Agree
# 17        97  100              Agree
# 18        97   60           Disagree
# 19        97   99     Strongly_Agree
# 20        98   17     Strongly_Agree
# 21        98   69              Agree
# 22        98   99            Neutral
# 23        98   89     Strongly_Agree
# ...

# %%
# The below is used to check how many person in our dataset

# %%
totalPerson=set(result1to10['person'])

# %%
# The len below have not deleted the error person: 96,97,98,254,313

# %%
len(totalPerson)
# Out:
# 185

# %% [markdown]
# # The below is contact "result1to10" and "articles" for news sentiment analysis

# %%
articles.head()
# Out:
#     id                                        article_url  \
# 0  100  https://www.washingtonpost.com/news/energy-env...
# 1   99  https://www.washingtonpost.com/news/energy-env...
# 2   98  https://www.washingtonpost.com/news/energy-env...
# 3   97  https://www.washingtonpost.com/news/energy-env...
# 4   96  https://www.washingtonpost.com/news/energy-env...
#
#                                                title          author  type  \
# 0  Alarming research finds humans are using up fa...  Chelsea Harvey  blog
# 1  Why dead coral reefs could mark the beginning ...  Chelsea Harvey  blog
# 2  Greenland’s melting is ‘feeding on itself,’ sc...    Chris Mooney  blog
# 3  Scientists confirm that warm ocean water is me...    Chris Mooney  blog
# 4  The Great Barrier Reef is bleaching yet again,...    Chris Mooney  blog
#
#                 category             subcategory  \
# 0  Climate & Environment  Energy and Environment
# 1  Climate & Environment  Energy and Environment
# ...

# %%
articlesSentiment = articles[["id","text"]]

# %%
articlesSentiment = pd.merge(result1to10, articlesSentiment, on='id')

# %%
#The below is used to make person in order

# %%
articlesSentiment = articlesSentiment.sort_values(by='person', ascending=True,ignore_index=True)

# %%
articlesSentiment.head()
# Out:
#    person   id         liked_news  \
# 0      96   39  Strongly_Disagree
# 1      96   31           Disagree
# 2      96  100            Neutral
# 3      96    7           Disagree
# 4      96   82     Strongly_Agree
#
#                                                 text
# 0  The Obama administration on Tuesday outlined a...
# 1  This story has been updated. <br><br> In a wor...
# 2  This story has been updated. <br><br> Freshwat...
# 3  It’s a huge paradox. <br><br> More and more re...
# 4  White House science adviser John Holdren’s com...

# %%
articlesSentiment.insert(4,'sentiment',"")  
articlesSentiment.insert(5,'rating(Y)',"")

# %%
# Renew the columns name

# %%
articlesSentiment.columns = ['person','newsId','liked_news','text','sentiment','rating(Y)']

# %%
articlesSentiment
# Out:
#       person  newsId         liked_news  \
# 0         96      39  Strongly_Disagree
# 1         96      31           Disagree
# 2         96     100            Neutral
# 3         96       7           Disagree
# 4         96      82     Strongly_Agree
# 5         96      28              Agree
# 6         96      61     Strongly_Agree
# 7         96      19     Strongly_Agree
# 8         96      32     Strongly_Agree
# 9         96      69  Strongly_Disagree
# 10        97      29              Agree
# 11        97      88  Strongly_Disagree
# 12        97      22           Disagree
# 13        97      27     Strongly_Agree
# 14        97      60           Disagree
# 15        97      99     Strongly_Agree
# 16        97     100              Agree
# 17        97      81              Agree
# 18        97      23           Disagree
# 19        97      33     Strongly_Agree
# 20        98      99            Neutral
# 21        98      36              Agree
# ...

# %%
articlesSentiment.shape
# Out:
# (1850, 6)

# %%
# The below is used to drop "wrong" person ID 96,97,98,254,313
articlesSentiment = articlesSentiment[articlesSentiment["person"] != 96]
articlesSentiment = articlesSentiment[articlesSentiment["person"] != 97]
articlesSentiment = articlesSentiment[articlesSentiment["person"] != 98]
articlesSentiment = articlesSentiment[articlesSentiment["person"] != 254]
articlesSentiment = articlesSentiment[articlesSentiment["person"] != 313]

# %%
articlesSentiment
# Out:
#       person  newsId         liked_news  \
# 30        99      60     Strongly_Agree
# 31        99      91     Strongly_Agree
# 32        99     100     Strongly_Agree
# 33        99      77     Strongly_Agree
# 34        99      57     Strongly_Agree
# 35        99      92     Strongly_Agree
# 36        99      89     Strongly_Agree
# 37        99      82     Strongly_Agree
# 38        99      41     Strongly_Agree
# 39        99      40     Strongly_Agree
# 40       100      37     Strongly_Agree
# 41       100      63     Strongly_Agree
# 42       100      47     Strongly_Agree
# 43       100      62     Strongly_Agree
# 44       100      87     Strongly_Agree
# 45       100       7     Strongly_Agree
# 46       100      69     Strongly_Agree
# 47       100      57     Strongly_Agree
# 48       100      84     Strongly_Agree
# 49       100      70     Strongly_Agree
# 50       101      54     Strongly_Agree
# 51       101      80              Agree
# ...

# %%
articlesSentiment.shape
# Out:
# (1800, 6)

# %%
# The below is for remove the abscent users, who do not join 1o news in the end, and be approved from Prolific

# %%
#result1and2 = result1and2[result1and2['person'].isin(df_evaluatechoices10['person'])]

# %%
#result1and2

# %%
# The below is used to check how many person in our dataset

# %%
#removeRow = result1and2[result1and2.duplicated(['person'], keep='last')]

# %%
# The shape below have not deleted the error person: 96,97,98,254,313

# %%
#removeRow.shape

# %%
#removeRow = result.sort_values(by='person', ascending=True,ignore_index=False)

# %%
#removeRow
