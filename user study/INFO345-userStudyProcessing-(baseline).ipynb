# %%
import pandas as pd
df_personal_info = pd.read_csv("data/baseline/Labels_Nudges.personal_info.csv")
#df_ghs_fk = pd.read_csv("C:/data/INFO345/baseline/Labels_Nudges.ghs_fk.csv")
df_evaluatechoices1 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices.csv")
df_evaluatechoices2 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices2.csv")
df_evaluatechoices3 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices3.csv")
df_evaluatechoices4 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices4.csv")
df_evaluatechoices5 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices5.csv")
df_evaluatechoices6 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices6.csv")
df_evaluatechoices7 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices7.csv")
df_evaluatechoices8 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices8.csv")
df_evaluatechoices9 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices9.csv")
df_evaluatechoices10 = pd.read_csv("data/baseline/Labels_Nudges.evaluatechoices10.csv")
#articles = pd.read_csv("C:/data/INFO345/baseline/Labels_Nudges.climatenewsBOM.csv")
#df2 = pd.DataFrame(csv_input2)
#personal_infoAndghs_fk = pd.merge(df_personal_info, df_ghs_fk, on='person')

# %% [markdown]
# # For demography

# %%
#The below is used to reove the wrong person ID: 11 (for testing)

# %%
df_personal_info = df_personal_info[df_personal_info["id"] != 11]

# %%
df_personal_info
# Out:
#     id          title                           created       age country  \
# 1   12  Personal_info  2022-11-09 12:56:45.270920+00:00    b18_24      AX
# 2   13  Personal_info  2022-11-09 13:15:44.371278+00:00    b25_35      US
# 3   14  Personal_info  2022-11-09 13:23:23.458293+00:00    b25_35      US
# 4   15  Personal_info  2022-11-09 13:28:03.744780+00:00    b35_45      US
# 5   16  Personal_info  2022-11-09 13:29:01.886365+00:00    b35_45      US
# 6   17  Personal_info  2022-11-09 13:30:02.965447+00:00    b18_24      US
# 7   18  Personal_info  2022-11-09 13:40:43.193219+00:00    b45_55      US
# 8   19  Personal_info  2022-11-09 13:40:53.530615+00:00    b18_24      US
# 9   20  Personal_info  2022-11-09 13:42:21.589793+00:00    b45_55      US
# 10  21  Personal_info  2022-11-09 13:44:02.494327+00:00    b25_35      US
# 11  22  Personal_info  2022-11-09 13:44:15.525316+00:00  bover_55      US
# 12  23  Personal_info  2022-11-09 13:50:24.995924+00:00    b45_55      US
# ...

# %%
df_personal_info = df_personal_info[df_personal_info['id'].isin(df_evaluatechoices10['person'])]

# %%
len(df_personal_info)
# Out:
# 15

# %%
df_personal_info.value_counts('gender')
# Out:
# gender
# Female            7
# Male              7
# refuse_to_disc    1
# dtype: int64

# %%
df_personal_info.value_counts('party')
# Out:
# party
# Democrats      9
# Republicans    6
# dtype: int64

# %% [markdown]
# # Below is used to testing news 1 contact news 2

# %%
df_evaluatechoices1
# Out:
#     id            title  person         liked_news      trust_news  \
# 0   10  EvaluateChoices      11              Agree           Agree
# 1   11  EvaluateChoices      12            Neutral        Disagree
# 2   12  EvaluateChoices      13     Strongly_Agree         Neutral
# 3   13  EvaluateChoices      14     Strongly_Agree         Neutral
# 4   14  EvaluateChoices      15     Strongly_Agree  Strongly_Agree
# 5   15  EvaluateChoices      16     Strongly_Agree           Agree
# 6   16  EvaluateChoices      19              Agree         Neutral
# 7   17  EvaluateChoices      20     Strongly_Agree         Neutral
# 8   18  EvaluateChoices      18              Agree         Neutral
# 9   19  EvaluateChoices      21     Strongly_Agree        Disagree
# 10  20  EvaluateChoices      22     Strongly_Agree           Agree
# 11  21  EvaluateChoices      25     Strongly_Agree         Neutral
# 12  22  EvaluateChoices      23     Strongly_Agree           Agree
# ...

# %%
# The below is used to extrct which column we want to keep in new df
df_evaluatechoices1 = df_evaluatechoices1[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices2 = df_evaluatechoices2[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices3 = df_evaluatechoices3[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices4 = df_evaluatechoices4[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices5 = df_evaluatechoices5[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices6 = df_evaluatechoices6[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices7 = df_evaluatechoices7[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices8 = df_evaluatechoices8[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices9 = df_evaluatechoices9[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]
df_evaluatechoices10 = df_evaluatechoices10[["person","created","liked_news","trust_news","fit_preference","recommend_news"]]

# %%
df_evaluatechoices1
# Out:
#     person  created         liked_news      trust_news     fit_preference  \
# 0       11        1              Agree           Agree              Agree
# 1       12        1            Neutral        Disagree           Disagree
# 2       13        1     Strongly_Agree         Neutral            Neutral
# 3       14        1     Strongly_Agree         Neutral            Neutral
# 4       15        1     Strongly_Agree  Strongly_Agree     Strongly_Agree
# 5       16        1     Strongly_Agree           Agree              Agree
# 6       19        1              Agree         Neutral            Neutral
# 7       20        1     Strongly_Agree         Neutral           Disagree
# 8       18        1              Agree         Neutral              Agree
# 9       21        1     Strongly_Agree        Disagree            Neutral
# 10      22        1     Strongly_Agree           Agree     Strongly_Agree
# 11      25        1     Strongly_Agree         Neutral              Agree
# ...

# %%
df_evaluatechoices2
# Out:
#     person  created         liked_news         trust_news     fit_preference  \
# 0       11        2           Disagree           Disagree            Neutral
# 1       13        2              Agree              Agree     Strongly_Agree
# 2       14        2     Strongly_Agree              Agree              Agree
# 3       16        2     Strongly_Agree              Agree              Agree
# 4       15        2     Strongly_Agree     Strongly_Agree              Agree
# 5       19        2           Disagree            Neutral            Neutral
# 6       21        2     Strongly_Agree           Disagree  Strongly_Disagree
# 7       18        2              Agree              Agree     Strongly_Agree
# 8       22        2     Strongly_Agree              Agree     Strongly_Agree
# 9       20        2     Strongly_Agree            Neutral              Agree
# 10      25        2     Strongly_Agree  Strongly_Disagree  Strongly_Disagree
# ...

# %%
# The below is used to contact two dataset for data analytics
result1and2 = pd.concat([df_evaluatechoices1, df_evaluatechoices2], axis="rows",ignore_index=True)

# %%
pd.set_option('display.max_rows', None)
result1and2
# Out:
#     person  created         liked_news         trust_news     fit_preference  \
# 0       11        1              Agree              Agree              Agree
# 1       12        1            Neutral           Disagree           Disagree
# 2       13        1     Strongly_Agree            Neutral            Neutral
# 3       14        1     Strongly_Agree            Neutral            Neutral
# 4       15        1     Strongly_Agree     Strongly_Agree     Strongly_Agree
# 5       16        1     Strongly_Agree              Agree              Agree
# 6       19        1              Agree            Neutral            Neutral
# 7       20        1     Strongly_Agree            Neutral           Disagree
# 8       18        1              Agree            Neutral              Agree
# 9       21        1     Strongly_Agree           Disagree            Neutral
# 10      22        1     Strongly_Agree              Agree     Strongly_Agree
# ...

# %%
result1and2.value_counts('liked_news')
# Out:
# liked_news
# Strongly_Agree       26
# Agree                 8
# Disagree              2
# Strongly_Disagree     2
# Neutral               1
# dtype: int64

# %%
result1and2.value_counts('liked_news')
# Out:
# liked_news
# Strongly_Agree       26
# Agree                 8
# Disagree              2
# Strongly_Disagree     2
# Neutral               1
# dtype: int64

# %%
#The below is used to make person in order

# %%
result1and2 = result1and2.sort_values(by='person', ascending=True,ignore_index=True)

# %%
result1and2
# Out:
#     person  created         liked_news         trust_news     fit_preference  \
# 0       11        1              Agree              Agree              Agree
# 1       11        2           Disagree           Disagree            Neutral
# 2       12        1            Neutral           Disagree           Disagree
# 3       13        1     Strongly_Agree            Neutral            Neutral
# 4       13        2              Agree              Agree     Strongly_Agree
# 5       14        2     Strongly_Agree              Agree              Agree
# 6       14        1     Strongly_Agree            Neutral            Neutral
# 7       15        2     Strongly_Agree     Strongly_Agree              Agree
# 8       15        1     Strongly_Agree     Strongly_Agree     Strongly_Agree
# 9       16        2     Strongly_Agree              Agree              Agree
# 10      16        1     Strongly_Agree              Agree              Agree
# ...

# %% [markdown]
# # The Main Part

# %%
# Now let's contact 10 dataframe

# %%
pdList = [df_evaluatechoices1, df_evaluatechoices2,df_evaluatechoices3,df_evaluatechoices4,df_evaluatechoices5,df_evaluatechoices6,df_evaluatechoices7,df_evaluatechoices8,df_evaluatechoices9,df_evaluatechoices10]  # List of your dataframes
result1to10 = pd.concat(pdList, axis="rows",ignore_index=True)

# %%
#pd.set_option('display.max_rows', None)
#result1to10

# %%
#khadiga
result1to10
# Out:
#      person  created         liked_news         trust_news     fit_preference  \
# 0        11        1              Agree              Agree              Agree
# 1        12        1            Neutral           Disagree           Disagree
# 2        13        1     Strongly_Agree            Neutral            Neutral
# 3        14        1     Strongly_Agree            Neutral            Neutral
# 4        15        1     Strongly_Agree     Strongly_Agree     Strongly_Agree
# 5        16        1     Strongly_Agree              Agree              Agree
# 6        19        1              Agree            Neutral            Neutral
# 7        20        1     Strongly_Agree            Neutral           Disagree
# 8        18        1              Agree            Neutral              Agree
# 9        21        1     Strongly_Agree           Disagree            Neutral
# 10       22        1     Strongly_Agree              Agree     Strongly_Agree
# ...

# %%
result1to10.value_counts('liked_news')
# Out:
# liked_news
# Strongly_Agree       81
# Agree                41
# Disagree             17
# Neutral              17
# Strongly_Disagree    12
# dtype: int64

# %%
result1to10.value_counts('trust_news')
# Out:
# trust_news
# Agree                63
# Neutral              47
# Disagree             35
# Strongly_Disagree    13
# Strongly_Agree       10
# dtype: int64

# %%
result1to10.value_counts('fit_preference')
# Out:
# fit_preference
# Agree                58
# Neutral              48
# Disagree             27
# Strongly_Agree       20
# Strongly_Disagree    15
# dtype: int64

# %%
result1to10.value_counts('recommend_news')
# Out:
# recommend_news
# Neutral              61
# Disagree             36
# Strongly_Disagree    32
# Agree                25
# Strongly_Agree       14
# dtype: int64

# %%
# The below is for remove the abscent users, who do not join 1o news in the end, and be approved from Prolific

# %%
##khadiga
result1to10 = result1to10[result1to10['person'].isin(df_evaluatechoices10['person'])]

# %%
#The below is used to make person in order

# %%
result1to10 = result1to10.sort_values(by='person', ascending=True,ignore_index=True)

# %%
result1to10.columns = ['person','id','liked_news',"trust_news","fit_preference","recommend_news"]

# %%
# Below is remove error person when online data collection

# %%
result1to10 = result1to10[result1to10["person"] != 11]

# %%
result1to10
# Out:
#      person  id         liked_news         trust_news     fit_preference  \
# 10       13   4            Neutral            Neutral              Agree
# 11       13   1     Strongly_Agree            Neutral            Neutral
# 12       13   9            Neutral            Neutral            Neutral
# 13       13   8            Neutral            Neutral              Agree
# 14       13   6              Agree            Neutral            Neutral
# 15       13   2              Agree              Agree     Strongly_Agree
# 16       13   5              Agree              Agree     Strongly_Agree
# 17       13   7            Neutral           Disagree           Disagree
# 18       13  10            Neutral           Disagree            Neutral
# 19       13   3              Agree              Agree              Agree
# 20       14   2     Strongly_Agree              Agree              Agree
# 21       14   7            Neutral            Neutral            Neutral
# ...

# %%
# The below is used to check how many person in our dataset

# %%
totalPerson=set(result1to10['person'])

# %%
# The len below have deleted the error person: 11

# %%
len(totalPerson)
# Out:
# 15

# %%
result1to10.value_counts('liked_news')
# Out:
# liked_news
# Strongly_Agree       72
# Agree                38
# Disagree             16
# Neutral              16
# Strongly_Disagree     8
# dtype: int64

# %%
result1to10.value_counts('trust_news')
# Out:
# trust_news
# Agree                56
# Neutral              46
# Disagree             29
# Strongly_Disagree    11
# Strongly_Agree        8
# dtype: int64

# %%
result1to10.value_counts('fit_preference')
# Out:
# fit_preference
# Agree                51
# Neutral              45
# Disagree             20
# Strongly_Agree       19
# Strongly_Disagree    15
# dtype: int64

# %%
result1to10.value_counts('recommend_news')
# Out:
# recommend_news
# Neutral              57
# Strongly_Disagree    32
# Disagree             31
# Agree                20
# Strongly_Agree       10
# dtype: int64
